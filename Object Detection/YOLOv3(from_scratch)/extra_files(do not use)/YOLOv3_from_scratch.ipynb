# %%
from __future__ import division

#import torch 
#import torch.nn as nn
#import torch.nn.functional as F 
#from torch.autograd import Variable
import numpy as np

import tensorflow as tf
from tensorflow import Variable
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, ZeroPadding2D, BatchNormalization, LeakyReLU, UpSampling2D, Concatenate
from tensorflow.keras.layers import Add, Input
from tensorflow.keras import Model

# %%
def parse_cfg(cfgfile):
    """
    Takes a configuration file
    
    Returns a list of blocks. Each blocks describes a block in the neural
    network to be built. Block is represented as a dictionary in the list
    
    """
    
    file = open(cfgfile, 'r')
    lines = file.read().split('\n')                        # store the lines in a list
    lines = [x for x in lines if len(x) > 0]               # get rid of the empty lines 
    lines = [x for x in lines if x[0] != '#']              # get rid of comments
    lines = [x.strip() for x in lines]           # get rid of fringe whitespaces
    
    block = {}
    blocks = []

    for line in lines:
        if line[0] == "[":               # This marks the start of a new block
            if len(block) != 0:          # If block is not empty, implies it is storing values of previous block.
                blocks.append(block)     # add it the blocks list
                block = {}               # re-init the block
            block["type"] = line[1:-1].rstrip()     
        else:
            key,value = line.split("=") 
            block[key.rstrip()] = value.lstrip()
    blocks.append(block)

    return blocks

class DetectionLayer(tf.keras.layers.Layer):
    def __init__(self, anchors, **kwargs):
        super().__init__(**kwargs)
        self.anchors = anchors

def create_modules(input_layer, blocks, num_classes):
    net_info = blocks[0]     #Captures the information about the input and pre-processing    
    module = Sequential()
    layer = input_layer
    prev_filters = 3
    
    outputs = {}
    output_filters = []
    filters = []
    scale = 0
    
    for index, x in enumerate(blocks[1:]):
        
        print(f"index:{index}")

        #check the type of block
        #create a new module for the block
        #append to module_list
        if (x["type"] == "convolutional"):
            
            #Get the info about the layer
            activation = x["activation"]
            try:
                batch_normalize = int(x["batch_normalize"])
                bias = False
            except:
                batch_normalize = 0
                bias = True

            filters= int(x["filters"])
            padding = int(x["pad"])
            kernel_size = int(x["size"])
            stride = int(x["stride"])
            
            print(f"layer{layer.get_shape().as_list()}")

            if padding:
                #model.add(ZeroPadding2D(padding=(kernel_size - 1) // 2))
                layer = ZeroPadding2D(padding=(kernel_size - 1) // 2)(layer)

            #Add the convolutional layer
            
            layer = Conv2D(filters, kernel_size, strides=stride, use_bias = bias, padding="valid",
                           name="conv_{0}".format(index))(layer)
            #model.add(conv, name="conv_{0}".format(index))

            #Add the Batch Norm Layer
            if batch_normalize:
                #model.add(BatchNormalization(), name="batch_norm_{0}".format(index))
                layer = BatchNormalization(name="batch_norm_{0}".format(index))(layer)

            #Check the activation. 
            #It is either Linear or a Leaky ReLU for YOLO
            if activation == "leaky":
                #model.add(LeakyReLU(alpha=0.1), name="leaky_{0}".format(index))
                layer = LeakyReLU(alpha=0.1, name="leaky_{0}".format(index))(layer)

        #If it's an upsampling layer
        #We use Bilinear2dUpsampling
        elif (x["type"] == "upsample"):
            stride = int(x["stride"])
            #model.add(UpSampling2D(size=stride, interpolation="bilinear"), name="upsample_{}".format(index))
            layer = UpSampling2D(size=stride, interpolation="bilinear",
                                 name="upsample_{}".format(index))(layer)
        
        #If it is a route layer
        elif (x["type"] == "route"):
            
            x["layers"] = x["layers"].split(',')
            
            start = int(x["layers"][0])
            if len(x["layers"]) > 1:
                end = int(x["layers"][1]) - index
                filters = output_filters[index + start] + output_filters[end]  # Index negatif :end - index
                #model.add(Concatenate([outputs[index + start], outputs[index + end]], axis=-1), name="route_{}".format(index))
                layer = Concatenate(name="route_{}".format(index))([outputs[index + start], outputs[index + end]])
            else:
                filters = output_filters[index + start]
                #model.add(Concatenate([outputs[index + start]], axis=-1), name="route_{}".format(index))
                #inputs = outputs[index + start]
                #layer = Concatenate([outputs[index + start]], name="route_{}".format(index))(layer)
                layer = outputs[index + start]
        

        #shortcut corresponds to skip connection
        elif x["type"] == "shortcut":
            
            from_ = int(x["from"])
            #inputs = outputs[index - 1] + outputs[index + from_]
            #model.add(Add()([outputs[index - 1], outputs[index + from_]]), name="shortcut_{}".format(index))
            layer = Add(name="shortcut_{}".format(index))([outputs[index - 1], outputs[index + from_]])
            
            #shortcut = EmptyLayer()
            #module.add_module("shortcut_{}".format(index), shortcut)
        
        # Yolo detection layer
        elif x["type"] == "yolo":
            mask = x["mask"].split(",")
            mask = [int(x) for x in mask]

            anchors = x["anchors"].split(",")
            anchors = [int(a) for a in anchors]
            anchors = [(anchors[i], anchors[i+1]) for i in range(0, len(anchors),2)]
            anchors = [anchors[i] for i in mask]

            detection = DetectionLayer(anchors)
            
            #model.add(detection, name="Detection_{}".format(index))
            #layer = Sequential([layer, detection])
            
            n_anchors = len(anchors)
            out_shape = layer.get_shape().as_list()
            layer = tf.reshape(layer, [-1, n_anchors * out_shape[1] * out_shape[2], 5 + num_classes])
            
            box_centers = layer[:, :, 0:2]
            box_shapes = layer[:, :, 2:4]
            confidence = layer[:, :, 4:5]
            classes = layer[:, :, 5:num_classes + 5]
            
            box_centers = tf.sigmoid(box_centers)
            confidence = tf.sigmoid(confidence)
            classes = tf.sigmoid(classes)
            
            anchors = tf.tile(anchors, [out_shape[1] * out_shape[2], 1])
            box_shapes = tf.exp(box_shapes) * tf.cast(anchors, dtype=tf.float32)
            
            x = tf.range(out_shape[1], dtype=tf.float32)
            y = tf.range(out_shape[2], dtype=tf.float32)
            
            cx, cy = tf.meshgrid(x, y)
            cx = tf.reshape(cx, (-1, 1))
            cy = tf.reshape(cy, (-1, 1))
            cxy = tf.concat([cx, cy], axis=-1)
            cxy = tf.tile(cxy, [1, n_anchors])
            cxy = tf.reshape(cxy, [1, -1, 2])
            
            strides = (input_layer.shape[1] // out_shape[1], \
                       input_layer.shape[2] // out_shape[2])
            box_centers = (box_centers + cxy) * strides
            prediction = tf.concat([box_centers, box_shapes, confidence, classes], axis=-1)
            print(f"prediction{prediction.shape}")
            if scale:
                out_pred = tf.concat([out_pred, prediction], axis=1)
            else:
                out_pred = prediction
                scale = 1
                
            print(f"out_pred{out_pred.shape}")
            print(f"current_layer{layer.shape}")
        
        #module_list.add(model)
        #prev_filters = filters
        outputs[index] = layer
        output_filters.append(filters)
        
    #return (net_info, layer)
    model = Model(input_layer, out_pred)
    model.summary()
    return model

# %%
def load_weights(model, blocks, weightfile):
    # Open the weights file
    fp = open(weightfile, "rb")
    # The first 5 values are header information
    np.fromfile(fp, dtype=np.int32, count=5)
    
    for i, block in enumerate(blocks[1:]):
        if (block["type"] == "convolutional"):
            conv_layer = model.get_layer('conv_' + str(i))
            print("layer: ",i+1,conv_layer)
            filters = conv_layer.filters
            k_size = conv_layer.kernel_size[0]
            in_dim = conv_layer.input_shape[-1]
            if "batch_normalize" in block:
                norm_layer = model.get_layer('batch_norm_' + str(i))
                print("layer: ",i+1,norm_layer)
                size = np.prod(norm_layer.get_weights()[0].shape)
                bn_weights = np.fromfile(fp, dtype=np.float32, count=4 * filters)
                # tf [gamma, beta, mean, variance]
                bn_weights = bn_weights.reshape((4, filters))[[1, 0, 2, 3]]
            else:
                conv_bias = np.fromfile(fp, dtype=np.float32, count=filters)
            # darknet shape (out_dim, in_dim, height, width)
            conv_shape = (filters, in_dim, k_size, k_size)
            conv_weights = np.fromfile(
                fp, dtype=np.float32, count=np.product(conv_shape))
            # tf shape (height, width, in_dim, out_dim)
            conv_weights = conv_weights.reshape(
                conv_shape).transpose([2, 3, 1, 0])
            if "batch_normalize" in block:
                norm_layer.set_weights(bn_weights)
                conv_layer.set_weights([conv_weights])
            else:
                conv_layer.set_weights([conv_weights, conv_bias])
                
    assert len(fp.read()) == 0, 'failed to read all data'
    fp.close()

# %%
weightfile = "./weights/yolov3.weights"
cfgfile = "cfg/yolov3.cfg"
input_shape = (416, 416, 3)
num_classes = 80

input_layer=Input(shape=input_shape)

blocks = parse_cfg("./cfg/yolov3.cfg")

model = create_modules(input_layer, blocks, num_classes)

load_weights(model, blocks, weightfile)

try:
    model.save_weights('./weights/yolov3_weights.tf')
    print('\nThe file \'yolov3_weights.tf\' has been saved successfully.')
except IOError:
    print("Couldn't write the file \'yolov3_weights.tf\'.")
# Out:
# index:0
# layer[None, 416, 416, 3]
# index:1
# layer[None, 416, 416, 32]
# index:2
# layer[None, 208, 208, 64]
# index:3
# layer[None, 208, 208, 32]
# index:4
# index:5
# layer[None, 208, 208, 64]
# index:6
# layer[None, 104, 104, 128]
# index:7
# layer[None, 104, 104, 64]
# index:8
# index:9
# layer[None, 104, 104, 128]
# index:10
# layer[None, 104, 104, 64]
# index:11
# index:12
# layer[None, 104, 104, 128]
# index:13
# layer[None, 52, 52, 256]
# index:14
# layer[None, 52, 52, 128]
# index:15
# index:16
# layer[None, 52, 52, 256]
# index:17
# layer[None, 52, 52, 128]
# index:18
# index:19
# layer[None, 52, 52, 256]
# index:20
# layer[None, 52, 52, 128]
# index:21
# index:22
# layer[None, 52, 52, 256]
# index:23
# layer[None, 52, 52, 128]
# index:24
# index:25
# layer[None, 52, 52, 256]
# index:26
# layer[None, 52, 52, 128]
# index:27
# index:28
# layer[None, 52, 52, 256]
# index:29
# layer[None, 52, 52, 128]
# index:30
# index:31
# layer[None, 52, 52, 256]
# index:32
# layer[None, 52, 52, 128]
# index:33
# index:34
# layer[None, 52, 52, 256]
# index:35
# layer[None, 52, 52, 128]
# index:36
# index:37
# layer[None, 52, 52, 256]
# index:38
# layer[None, 26, 26, 512]
# index:39
# layer[None, 26, 26, 256]
# index:40
# index:41
# layer[None, 26, 26, 512]
# index:42
# layer[None, 26, 26, 256]
# index:43
# index:44
# layer[None, 26, 26, 512]
# index:45
# layer[None, 26, 26, 256]
# index:46
# index:47
# layer[None, 26, 26, 512]
# index:48
# layer[None, 26, 26, 256]
# index:49
# index:50
# layer[None, 26, 26, 512]
# index:51
# layer[None, 26, 26, 256]
# index:52
# index:53
# layer[None, 26, 26, 512]
# index:54
# layer[None, 26, 26, 256]
# index:55
# index:56
# layer[None, 26, 26, 512]
# index:57
# layer[None, 26, 26, 256]
# index:58
# index:59
# layer[None, 26, 26, 512]
# index:60
# layer[None, 26, 26, 256]
# index:61
# index:62
# layer[None, 26, 26, 512]
# index:63
# layer[None, 13, 13, 1024]
# index:64
# layer[None, 13, 13, 512]
# index:65
# index:66
# layer[None, 13, 13, 1024]
# index:67
# layer[None, 13, 13, 512]
# index:68
# index:69
# layer[None, 13, 13, 1024]
# index:70
# layer[None, 13, 13, 512]
# index:71
# index:72
# layer[None, 13, 13, 1024]
# index:73
# layer[None, 13, 13, 512]
# index:74
# index:75
# layer[None, 13, 13, 1024]
# index:76
# layer[None, 13, 13, 512]
# index:77
# layer[None, 13, 13, 1024]
# index:78
# layer[None, 13, 13, 512]
# index:79
# layer[None, 13, 13, 1024]
# index:80
# layer[None, 13, 13, 512]
# index:81
# layer[None, 13, 13, 1024]
# index:82
# prediction(None, 507, 85)
# out_pred(None, 507, 85)
# current_layer(None, 507, 85)
# index:83
# index:84
# layer[None, 13, 13, 512]
# index:85
# index:86
# index:87
# layer[None, 26, 26, 768]
# index:88
# layer[None, 26, 26, 256]
# index:89
# layer[None, 26, 26, 512]
# index:90
# layer[None, 26, 26, 256]
# index:91
# layer[None, 26, 26, 512]
# index:92
# layer[None, 26, 26, 256]
# index:93
# layer[None, 26, 26, 512]
# index:94
# prediction(None, 2028, 85)
# out_pred(None, 2535, 85)
# current_layer(None, 2028, 85)
# index:95
# index:96
# layer[None, 26, 26, 256]
# index:97
# index:98
# index:99
# layer[None, 52, 52, 384]
# index:100
# layer[None, 52, 52, 128]
# index:101
# layer[None, 52, 52, 256]
# index:102
# layer[None, 52, 52, 128]
# index:103
# layer[None, 52, 52, 256]
# index:104
# layer[None, 52, 52, 128]
# index:105
# layer[None, 52, 52, 256]
# index:106
# prediction(None, 8112, 85)
# out_pred(None, 10647, 85)
# current_layer(None, 8112, 85)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 418, 418, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv_0 (Conv2D)                 (None, 416, 416, 32) 864         zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_norm_0 (BatchNormalizatio (None, 416, 416, 32) 128         conv_0[0][0]
# __________________________________________________________________________________________________
# leaky_0 (LeakyReLU)             (None, 416, 416, 32) 0           batch_norm_0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 418, 418, 32) 0           leaky_0[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 208, 208, 64) 18432       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_norm_1 (BatchNormalizatio (None, 208, 208, 64) 256         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_1 (LeakyReLU)             (None, 208, 208, 64) 0           batch_norm_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 208, 208, 64) 0           leaky_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 208, 208, 32) 2048        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_norm_2 (BatchNormalizatio (None, 208, 208, 32) 128         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_2 (LeakyReLU)             (None, 208, 208, 32) 0           batch_norm_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 210, 210, 32) 0           leaky_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 208, 208, 64) 18432       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_norm_3 (BatchNormalizatio (None, 208, 208, 64) 256         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_3 (LeakyReLU)             (None, 208, 208, 64) 0           batch_norm_3[0][0]
# __________________________________________________________________________________________________
# shortcut_4 (Add)                (None, 208, 208, 64) 0           leaky_3[0][0]
#                                                                  leaky_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 210, 210, 64) 0           shortcut_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 104, 104, 128 73728       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_norm_5 (BatchNormalizatio (None, 104, 104, 128 512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_5 (LeakyReLU)             (None, 104, 104, 128 0           batch_norm_5[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 104, 104, 128 0           leaky_5[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 104, 104, 64) 8192        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_norm_6 (BatchNormalizatio (None, 104, 104, 64) 256         conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_6 (LeakyReLU)             (None, 104, 104, 64) 0           batch_norm_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 106, 106, 64) 0           leaky_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 104, 104, 128 73728       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_norm_7 (BatchNormalizatio (None, 104, 104, 128 512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_7 (LeakyReLU)             (None, 104, 104, 128 0           batch_norm_7[0][0]
# __________________________________________________________________________________________________
# shortcut_8 (Add)                (None, 104, 104, 128 0           leaky_7[0][0]
#                                                                  leaky_5[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 104, 104, 128 0           shortcut_8[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 104, 104, 64) 8192        zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_norm_9 (BatchNormalizatio (None, 104, 104, 64) 256         conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_9 (LeakyReLU)             (None, 104, 104, 64) 0           batch_norm_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 106, 106, 64) 0           leaky_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 104, 104, 128 73728       zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# batch_norm_10 (BatchNormalizati (None, 104, 104, 128 512         conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_10 (LeakyReLU)            (None, 104, 104, 128 0           batch_norm_10[0][0]
# __________________________________________________________________________________________________
# shortcut_11 (Add)               (None, 104, 104, 128 0           leaky_10[0][0]
#                                                                  shortcut_8[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 106, 106, 128 0           shortcut_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# batch_norm_12 (BatchNormalizati (None, 52, 52, 256)  1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_12 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_12[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 52, 52, 256)  0           leaky_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 52, 52, 128)  32768       zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# batch_norm_13 (BatchNormalizati (None, 52, 52, 128)  512         conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_13 (LeakyReLU)            (None, 52, 52, 128)  0           batch_norm_13[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 54, 54, 128)  0           leaky_13[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# batch_norm_14 (BatchNormalizati (None, 52, 52, 256)  1024        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_14 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_14[0][0]
# __________________________________________________________________________________________________
# shortcut_15 (Add)               (None, 52, 52, 256)  0           leaky_14[0][0]
#                                                                  leaky_12[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 52, 52, 256)  0           shortcut_15[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 52, 52, 128)  32768       zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# batch_norm_16 (BatchNormalizati (None, 52, 52, 128)  512         conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_16 (LeakyReLU)            (None, 52, 52, 128)  0           batch_norm_16[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 54, 54, 128)  0           leaky_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# batch_norm_17 (BatchNormalizati (None, 52, 52, 256)  1024        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_17 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_17[0][0]
# __________________________________________________________________________________________________
# shortcut_18 (Add)               (None, 52, 52, 256)  0           leaky_17[0][0]
#                                                                  shortcut_15[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 52, 52, 256)  0           shortcut_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 52, 52, 128)  32768       zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# batch_norm_19 (BatchNormalizati (None, 52, 52, 128)  512         conv_19[0][0]
# __________________________________________________________________________________________________
# leaky_19 (LeakyReLU)            (None, 52, 52, 128)  0           batch_norm_19[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 54, 54, 128)  0           leaky_19[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# batch_norm_20 (BatchNormalizati (None, 52, 52, 256)  1024        conv_20[0][0]
# __________________________________________________________________________________________________
# leaky_20 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_20[0][0]
# __________________________________________________________________________________________________
# shortcut_21 (Add)               (None, 52, 52, 256)  0           leaky_20[0][0]
#                                                                  shortcut_18[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 52, 52, 256)  0           shortcut_21[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 52, 52, 128)  32768       zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# batch_norm_22 (BatchNormalizati (None, 52, 52, 128)  512         conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_22 (LeakyReLU)            (None, 52, 52, 128)  0           batch_norm_22[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 54, 54, 128)  0           leaky_22[0][0]
# __________________________________________________________________________________________________
# conv_23 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# batch_norm_23 (BatchNormalizati (None, 52, 52, 256)  1024        conv_23[0][0]
# __________________________________________________________________________________________________
# leaky_23 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_23[0][0]
# __________________________________________________________________________________________________
# shortcut_24 (Add)               (None, 52, 52, 256)  0           leaky_23[0][0]
#                                                                  shortcut_21[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 52, 52, 256)  0           shortcut_24[0][0]
# __________________________________________________________________________________________________
# conv_25 (Conv2D)                (None, 52, 52, 128)  32768       zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# batch_norm_25 (BatchNormalizati (None, 52, 52, 128)  512         conv_25[0][0]
# __________________________________________________________________________________________________
# leaky_25 (LeakyReLU)            (None, 52, 52, 128)  0           batch_norm_25[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 54, 54, 128)  0           leaky_25[0][0]
# __________________________________________________________________________________________________
# conv_26 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# batch_norm_26 (BatchNormalizati (None, 52, 52, 256)  1024        conv_26[0][0]
# __________________________________________________________________________________________________
# leaky_26 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_26[0][0]
# __________________________________________________________________________________________________
# shortcut_27 (Add)               (None, 52, 52, 256)  0           leaky_26[0][0]
#                                                                  shortcut_24[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 52, 52, 256)  0           shortcut_27[0][0]
# __________________________________________________________________________________________________
# conv_28 (Conv2D)                (None, 52, 52, 128)  32768       zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# batch_norm_28 (BatchNormalizati (None, 52, 52, 128)  512         conv_28[0][0]
# __________________________________________________________________________________________________
# leaky_28 (LeakyReLU)            (None, 52, 52, 128)  0           batch_norm_28[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 54, 54, 128)  0           leaky_28[0][0]
# __________________________________________________________________________________________________
# conv_29 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# batch_norm_29 (BatchNormalizati (None, 52, 52, 256)  1024        conv_29[0][0]
# __________________________________________________________________________________________________
# leaky_29 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_29[0][0]
# __________________________________________________________________________________________________
# shortcut_30 (Add)               (None, 52, 52, 256)  0           leaky_29[0][0]
#                                                                  shortcut_27[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 52, 52, 256)  0           shortcut_30[0][0]
# __________________________________________________________________________________________________
# conv_31 (Conv2D)                (None, 52, 52, 128)  32768       zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# batch_norm_31 (BatchNormalizati (None, 52, 52, 128)  512         conv_31[0][0]
# __________________________________________________________________________________________________
# leaky_31 (LeakyReLU)            (None, 52, 52, 128)  0           batch_norm_31[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 54, 54, 128)  0           leaky_31[0][0]
# __________________________________________________________________________________________________
# conv_32 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_23[0][0]
# __________________________________________________________________________________________________
# batch_norm_32 (BatchNormalizati (None, 52, 52, 256)  1024        conv_32[0][0]
# __________________________________________________________________________________________________
# leaky_32 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_32[0][0]
# __________________________________________________________________________________________________
# shortcut_33 (Add)               (None, 52, 52, 256)  0           leaky_32[0][0]
#                                                                  shortcut_30[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2 (None, 52, 52, 256)  0           shortcut_33[0][0]
# __________________________________________________________________________________________________
# conv_34 (Conv2D)                (None, 52, 52, 128)  32768       zero_padding2d_24[0][0]
# __________________________________________________________________________________________________
# batch_norm_34 (BatchNormalizati (None, 52, 52, 128)  512         conv_34[0][0]
# __________________________________________________________________________________________________
# leaky_34 (LeakyReLU)            (None, 52, 52, 128)  0           batch_norm_34[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2 (None, 54, 54, 128)  0           leaky_34[0][0]
# __________________________________________________________________________________________________
# conv_35 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_25[0][0]
# __________________________________________________________________________________________________
# batch_norm_35 (BatchNormalizati (None, 52, 52, 256)  1024        conv_35[0][0]
# __________________________________________________________________________________________________
# leaky_35 (LeakyReLU)            (None, 52, 52, 256)  0           batch_norm_35[0][0]
# __________________________________________________________________________________________________
# shortcut_36 (Add)               (None, 52, 52, 256)  0           leaky_35[0][0]
#                                                                  shortcut_33[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_26 (ZeroPadding2 (None, 54, 54, 256)  0           shortcut_36[0][0]
# __________________________________________________________________________________________________
# conv_37 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_26[0][0]
# __________________________________________________________________________________________________
# batch_norm_37 (BatchNormalizati (None, 26, 26, 512)  2048        conv_37[0][0]
# __________________________________________________________________________________________________
# leaky_37 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_37[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2 (None, 26, 26, 512)  0           leaky_37[0][0]
# __________________________________________________________________________________________________
# conv_38 (Conv2D)                (None, 26, 26, 256)  131072      zero_padding2d_27[0][0]
# __________________________________________________________________________________________________
# batch_norm_38 (BatchNormalizati (None, 26, 26, 256)  1024        conv_38[0][0]
# __________________________________________________________________________________________________
# leaky_38 (LeakyReLU)            (None, 26, 26, 256)  0           batch_norm_38[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2 (None, 28, 28, 256)  0           leaky_38[0][0]
# __________________________________________________________________________________________________
# conv_39 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_28[0][0]
# __________________________________________________________________________________________________
# batch_norm_39 (BatchNormalizati (None, 26, 26, 512)  2048        conv_39[0][0]
# __________________________________________________________________________________________________
# leaky_39 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_39[0][0]
# __________________________________________________________________________________________________
# shortcut_40 (Add)               (None, 26, 26, 512)  0           leaky_39[0][0]
#                                                                  leaky_37[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2 (None, 26, 26, 512)  0           shortcut_40[0][0]
# __________________________________________________________________________________________________
# conv_41 (Conv2D)                (None, 26, 26, 256)  131072      zero_padding2d_29[0][0]
# __________________________________________________________________________________________________
# batch_norm_41 (BatchNormalizati (None, 26, 26, 256)  1024        conv_41[0][0]
# __________________________________________________________________________________________________
# leaky_41 (LeakyReLU)            (None, 26, 26, 256)  0           batch_norm_41[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 28, 28, 256)  0           leaky_41[0][0]
# __________________________________________________________________________________________________
# conv_42 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_30[0][0]
# __________________________________________________________________________________________________
# batch_norm_42 (BatchNormalizati (None, 26, 26, 512)  2048        conv_42[0][0]
# __________________________________________________________________________________________________
# leaky_42 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_42[0][0]
# __________________________________________________________________________________________________
# shortcut_43 (Add)               (None, 26, 26, 512)  0           leaky_42[0][0]
#                                                                  shortcut_40[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2 (None, 26, 26, 512)  0           shortcut_43[0][0]
# __________________________________________________________________________________________________
# conv_44 (Conv2D)                (None, 26, 26, 256)  131072      zero_padding2d_31[0][0]
# __________________________________________________________________________________________________
# batch_norm_44 (BatchNormalizati (None, 26, 26, 256)  1024        conv_44[0][0]
# __________________________________________________________________________________________________
# leaky_44 (LeakyReLU)            (None, 26, 26, 256)  0           batch_norm_44[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2 (None, 28, 28, 256)  0           leaky_44[0][0]
# __________________________________________________________________________________________________
# conv_45 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_32[0][0]
# __________________________________________________________________________________________________
# batch_norm_45 (BatchNormalizati (None, 26, 26, 512)  2048        conv_45[0][0]
# __________________________________________________________________________________________________
# leaky_45 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_45[0][0]
# __________________________________________________________________________________________________
# shortcut_46 (Add)               (None, 26, 26, 512)  0           leaky_45[0][0]
#                                                                  shortcut_43[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2 (None, 26, 26, 512)  0           shortcut_46[0][0]
# __________________________________________________________________________________________________
# conv_47 (Conv2D)                (None, 26, 26, 256)  131072      zero_padding2d_33[0][0]
# __________________________________________________________________________________________________
# batch_norm_47 (BatchNormalizati (None, 26, 26, 256)  1024        conv_47[0][0]
# __________________________________________________________________________________________________
# leaky_47 (LeakyReLU)            (None, 26, 26, 256)  0           batch_norm_47[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_34 (ZeroPadding2 (None, 28, 28, 256)  0           leaky_47[0][0]
# __________________________________________________________________________________________________
# conv_48 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_34[0][0]
# __________________________________________________________________________________________________
# batch_norm_48 (BatchNormalizati (None, 26, 26, 512)  2048        conv_48[0][0]
# __________________________________________________________________________________________________
# leaky_48 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_48[0][0]
# __________________________________________________________________________________________________
# shortcut_49 (Add)               (None, 26, 26, 512)  0           leaky_48[0][0]
#                                                                  shortcut_46[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_35 (ZeroPadding2 (None, 26, 26, 512)  0           shortcut_49[0][0]
# __________________________________________________________________________________________________
# conv_50 (Conv2D)                (None, 26, 26, 256)  131072      zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# batch_norm_50 (BatchNormalizati (None, 26, 26, 256)  1024        conv_50[0][0]
# __________________________________________________________________________________________________
# leaky_50 (LeakyReLU)            (None, 26, 26, 256)  0           batch_norm_50[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_36 (ZeroPadding2 (None, 28, 28, 256)  0           leaky_50[0][0]
# __________________________________________________________________________________________________
# conv_51 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_36[0][0]
# __________________________________________________________________________________________________
# batch_norm_51 (BatchNormalizati (None, 26, 26, 512)  2048        conv_51[0][0]
# __________________________________________________________________________________________________
# leaky_51 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_51[0][0]
# __________________________________________________________________________________________________
# shortcut_52 (Add)               (None, 26, 26, 512)  0           leaky_51[0][0]
#                                                                  shortcut_49[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_37 (ZeroPadding2 (None, 26, 26, 512)  0           shortcut_52[0][0]
# __________________________________________________________________________________________________
# conv_53 (Conv2D)                (None, 26, 26, 256)  131072      zero_padding2d_37[0][0]
# __________________________________________________________________________________________________
# batch_norm_53 (BatchNormalizati (None, 26, 26, 256)  1024        conv_53[0][0]
# __________________________________________________________________________________________________
# leaky_53 (LeakyReLU)            (None, 26, 26, 256)  0           batch_norm_53[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_38 (ZeroPadding2 (None, 28, 28, 256)  0           leaky_53[0][0]
# __________________________________________________________________________________________________
# conv_54 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_38[0][0]
# __________________________________________________________________________________________________
# batch_norm_54 (BatchNormalizati (None, 26, 26, 512)  2048        conv_54[0][0]
# __________________________________________________________________________________________________
# leaky_54 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_54[0][0]
# __________________________________________________________________________________________________
# shortcut_55 (Add)               (None, 26, 26, 512)  0           leaky_54[0][0]
#                                                                  shortcut_52[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_39 (ZeroPadding2 (None, 26, 26, 512)  0           shortcut_55[0][0]
# __________________________________________________________________________________________________
# conv_56 (Conv2D)                (None, 26, 26, 256)  131072      zero_padding2d_39[0][0]
# __________________________________________________________________________________________________
# batch_norm_56 (BatchNormalizati (None, 26, 26, 256)  1024        conv_56[0][0]
# __________________________________________________________________________________________________
# leaky_56 (LeakyReLU)            (None, 26, 26, 256)  0           batch_norm_56[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_40 (ZeroPadding2 (None, 28, 28, 256)  0           leaky_56[0][0]
# __________________________________________________________________________________________________
# conv_57 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_40[0][0]
# __________________________________________________________________________________________________
# batch_norm_57 (BatchNormalizati (None, 26, 26, 512)  2048        conv_57[0][0]
# __________________________________________________________________________________________________
# leaky_57 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_57[0][0]
# __________________________________________________________________________________________________
# shortcut_58 (Add)               (None, 26, 26, 512)  0           leaky_57[0][0]
#                                                                  shortcut_55[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_41 (ZeroPadding2 (None, 26, 26, 512)  0           shortcut_58[0][0]
# __________________________________________________________________________________________________
# conv_59 (Conv2D)                (None, 26, 26, 256)  131072      zero_padding2d_41[0][0]
# __________________________________________________________________________________________________
# batch_norm_59 (BatchNormalizati (None, 26, 26, 256)  1024        conv_59[0][0]
# __________________________________________________________________________________________________
# leaky_59 (LeakyReLU)            (None, 26, 26, 256)  0           batch_norm_59[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_42 (ZeroPadding2 (None, 28, 28, 256)  0           leaky_59[0][0]
# __________________________________________________________________________________________________
# conv_60 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_42[0][0]
# __________________________________________________________________________________________________
# batch_norm_60 (BatchNormalizati (None, 26, 26, 512)  2048        conv_60[0][0]
# __________________________________________________________________________________________________
# leaky_60 (LeakyReLU)            (None, 26, 26, 512)  0           batch_norm_60[0][0]
# __________________________________________________________________________________________________
# shortcut_61 (Add)               (None, 26, 26, 512)  0           leaky_60[0][0]
#                                                                  shortcut_58[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_43 (ZeroPadding2 (None, 28, 28, 512)  0           shortcut_61[0][0]
# __________________________________________________________________________________________________
# conv_62 (Conv2D)                (None, 13, 13, 1024) 4718592     zero_padding2d_43[0][0]
# __________________________________________________________________________________________________
# batch_norm_62 (BatchNormalizati (None, 13, 13, 1024) 4096        conv_62[0][0]
# __________________________________________________________________________________________________
# leaky_62 (LeakyReLU)            (None, 13, 13, 1024) 0           batch_norm_62[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_44 (ZeroPadding2 (None, 13, 13, 1024) 0           leaky_62[0][0]
# __________________________________________________________________________________________________
# conv_63 (Conv2D)                (None, 13, 13, 512)  524288      zero_padding2d_44[0][0]
# __________________________________________________________________________________________________
# batch_norm_63 (BatchNormalizati (None, 13, 13, 512)  2048        conv_63[0][0]
# __________________________________________________________________________________________________
# leaky_63 (LeakyReLU)            (None, 13, 13, 512)  0           batch_norm_63[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_45 (ZeroPadding2 (None, 15, 15, 512)  0           leaky_63[0][0]
# __________________________________________________________________________________________________
# conv_64 (Conv2D)                (None, 13, 13, 1024) 4718592     zero_padding2d_45[0][0]
# __________________________________________________________________________________________________
# batch_norm_64 (BatchNormalizati (None, 13, 13, 1024) 4096        conv_64[0][0]
# __________________________________________________________________________________________________
# leaky_64 (LeakyReLU)            (None, 13, 13, 1024) 0           batch_norm_64[0][0]
# __________________________________________________________________________________________________
# shortcut_65 (Add)               (None, 13, 13, 1024) 0           leaky_64[0][0]
#                                                                  leaky_62[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_46 (ZeroPadding2 (None, 13, 13, 1024) 0           shortcut_65[0][0]
# __________________________________________________________________________________________________
# conv_66 (Conv2D)                (None, 13, 13, 512)  524288      zero_padding2d_46[0][0]
# __________________________________________________________________________________________________
# batch_norm_66 (BatchNormalizati (None, 13, 13, 512)  2048        conv_66[0][0]
# __________________________________________________________________________________________________
# leaky_66 (LeakyReLU)            (None, 13, 13, 512)  0           batch_norm_66[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_47 (ZeroPadding2 (None, 15, 15, 512)  0           leaky_66[0][0]
# __________________________________________________________________________________________________
# conv_67 (Conv2D)                (None, 13, 13, 1024) 4718592     zero_padding2d_47[0][0]
# __________________________________________________________________________________________________
# batch_norm_67 (BatchNormalizati (None, 13, 13, 1024) 4096        conv_67[0][0]
# __________________________________________________________________________________________________
# leaky_67 (LeakyReLU)            (None, 13, 13, 1024) 0           batch_norm_67[0][0]
# __________________________________________________________________________________________________
# shortcut_68 (Add)               (None, 13, 13, 1024) 0           leaky_67[0][0]
#                                                                  shortcut_65[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_48 (ZeroPadding2 (None, 13, 13, 1024) 0           shortcut_68[0][0]
# ...
# __________________________________________________________________________________________________
# tf.math.sigmoid_8 (TFOpLambda)  (None, 8112, 80)     0           tf.__operators__.getitem_11[0][0]
# __________________________________________________________________________________________________
# tf.concat_2 (TFOpLambda)        (None, 2535, 85)     0           tf.concat[0][0]
#                                                                  tf.concat_1[0][0]
# __________________________________________________________________________________________________
# tf.concat_3 (TFOpLambda)        (None, 8112, 85)     0           tf.math.multiply_5[0][0]
#                                                                  tf.math.multiply_4[0][0]
#                                                                  tf.math.sigmoid_7[0][0]
#                                                                  tf.math.sigmoid_8[0][0]
# __________________________________________________________________________________________________
# tf.concat_4 (TFOpLambda)        (None, 10647, 85)    0           tf.concat_2[0][0]
#                                                                  tf.concat_3[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# layer:  1 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788738a30>
# layer:  1 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97885165e0>
# layer:  2 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788478100>
# layer:  2 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978848ea60>
# layer:  3 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788498cd0>
# layer:  3 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788738310>
# layer:  4 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788516610>
# layer:  4 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788429d30>
# layer:  6 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788429310>
# layer:  6 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97884781c0>
# layer:  7 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978843fe20>
# layer:  7 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788499640>
# layer:  8 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97885164c0>
# layer:  8 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788516490>
# layer:  10 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97884a32b0>
# layer:  10 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978844a640>
# layer:  11 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978843a640>
# layer:  11 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788478850>
# layer:  13 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97884658b0>
# layer:  13 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883ebb20>
# layer:  14 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883f1e80>
# layer:  14 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883ebb50>
# layer:  15 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883ffd60>
# layer:  15 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883f8370>
# layer:  17 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788465160>
# layer:  17 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883f7d60>
# layer:  18 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883f12b0>
# layer:  18 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883f1d60>
# layer:  20 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978841a2e0>
# layer:  20 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788425190>
# layer:  21 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978841af40>
# layer:  21 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788427040>
# layer:  23 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883bf100>
# layer:  23 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883ff610>
# layer:  24 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788417b80>
# layer:  24 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788478910>
# layer:  26 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978840adc0>
# layer:  26 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883cb3d0>
# layer:  27 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97884505e0>
# layer:  27 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788450fa0>
# layer:  29 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883cc040>
# layer:  29 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883d60a0>
# layer:  30 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883e55e0>
# layer:  30 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883e55b0>
# layer:  32 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883e5e20>
# layer:  32 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978837ebe0>
# layer:  33 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883753a0>
# layer:  33 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978837ea90>
# layer:  35 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788394550>
# layer:  35 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788394730>
# layer:  36 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883e57f0>
# layer:  36 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883948b0>
# layer:  38 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978832f730>
# layer:  38 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978832c160>
# layer:  39 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883e16d0>
# layer:  39 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883e1e20>
# layer:  40 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883e16a0>
# layer:  40 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97884558e0>
# layer:  42 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788339700>
# layer:  42 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788342730>
# layer:  43 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788342880>
# layer:  43 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883cc7f0>
# layer:  45 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788331700>
# layer:  45 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978833bbb0>
# layer:  46 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978835dc10>
# layer:  46 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978835de50>
# layer:  48 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883561f0>
# layer:  48 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882f0a30>
# layer:  49 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788361820>
# layer:  49 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788365b80>
# layer:  51 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883108b0>
# layer:  51 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883311c0>
# layer:  52 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788310cd0>
# layer:  52 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788321ee0>
# layer:  54 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978832ff70>
# layer:  54 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97883654f0>
# layer:  55 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883cfc70>
# layer:  55 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788339d90>
# layer:  57 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788313880>
# layer:  57 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978836df40>
# layer:  58 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97883e1ac0>
# layer:  58 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882abd60>
# layer:  60 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97882ab0a0>
# layer:  60 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882c6550>
# layer:  61 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97882ab310>
# layer:  61 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882b7760>
# layer:  63 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97882c6160>
# layer:  63 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882c6730>
# layer:  64 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97882e2430>
# layer:  64 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882cb8e0>
# layer:  65 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97882e2af0>
# layer:  65 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882689a0>
# layer:  67 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788276820>
# layer:  67 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788276f70>
# layer:  68 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97882823d0>
# layer:  68 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788282550>
# layer:  70 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9789766a00>
# layer:  70 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97897ca130>
# layer:  71 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9789900ee0>
# layer:  71 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97899008e0>
# layer:  73 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97898e59a0>
# layer:  73 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978bfc9700>
# layer:  74 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788516730>
# layer:  74 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882addc0>
# layer:  76 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97882ad460>
# layer:  76 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97897275e0>
# layer:  77 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9789722f70>
# layer:  77 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788294e80>
# layer:  78 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97882985b0>
# layer:  78 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97897218b0>
# layer:  79 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978829af70>
# layer:  79 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978829abe0>
# layer:  80 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978822ab20>
# layer:  80 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788298520>
# layer:  81 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978823a9a0>
# layer:  81 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978822d910>
# layer:  82 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978822d0d0>
# layer:  85 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788253fa0>
# layer:  85 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788282610>
# layer:  88 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978825fc40>
# layer:  88 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97881eb0a0>
# layer:  89 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881f1070>
# layer:  89 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97881f98e0>
# layer:  90 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881ffa60>
# layer:  90 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97881fff40>
# layer:  91 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f978820a040>
# layer:  91 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978820afd0>
# layer:  92 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788215c70>
# layer:  92 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788213e80>
# layer:  93 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788226250>
# layer:  93 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97882219d0>
# layer:  94 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f9788221160>
# layer:  97 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881bfb80>
# layer:  97 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97881c29a0>
# layer:  100 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881d0520>
# layer:  100 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788249a30>
# layer:  101 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881d8910>
# layer:  101 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97881d68e0>
# layer:  102 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881de220>
# layer:  102 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97881e6c70>
# layer:  103 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881def40>
# layer:  103 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f9788178bb0>
# layer:  104 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881780d0>
# layer:  104 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f978818c5b0>
# layer:  105 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881788e0>
# layer:  105 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f97881976d0>
# layer:  106 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f97881a0460>
#
# The file 'yolov3_weights.tf' has been saved successfully.

# %%
blocks = parse_cfg("./cfg/yolov3.cfg")
blocks
# Out:
# [{'type': 'net',
#   'batch': '64',
#   'subdivisions': '16',
#   'width': '608',
#   'height': '608',
#   'channels': '3',
#   'momentum': '0.9',
#   'decay': '0.0005',
#   'angle': '0',
#   'saturation': '1.5',
#   'exposure': '1.5',
#   'hue': '.1',
#   'learning_rate': '0.001',
#   'burn_in': '1000',
#   'max_batches': '500200',
#   'policy': 'steps',
#   'steps': '400000,450000',
#   'scales': '.1,.1'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '32',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '64',
#   'size': '3',
#   'stride': '2',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '32',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '64',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '3',
#   'stride': '2',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '64',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '64',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '2',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '2',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '1024',
#   'size': '3',
#   'stride': '2',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '1024',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '1024',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '1024',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '1024',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'shortcut', 'from': '-3', 'activation': 'linear'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '1024',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '1024',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '512',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '1024',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'filters': '255',
#   'activation': 'linear'},
#  {'type': 'yolo',
#   'mask': '6,7,8',
#   'anchors': '10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326',
#   'classes': '80',
#   'num': '9',
#   'jitter': '.3',
#   'ignore_thresh': '.7',
#   'truth_thresh': '1',
#   'random': '1'},
#  {'type': 'route', 'layers': '-4'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'upsample', 'stride': '2'},
#  {'type': 'route', 'layers': '-1, 61'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '512',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '512',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '256',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '512',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'filters': '255',
#   'activation': 'linear'},
#  {'type': 'yolo',
#   'mask': '3,4,5',
#   'anchors': '10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326',
#   'classes': '80',
#   'num': '9',
#   'jitter': '.3',
#   'ignore_thresh': '.7',
#   'truth_thresh': '1',
#   'random': '1'},
#  {'type': 'route', 'layers': '-4'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'upsample', 'stride': '2'},
#  {'type': 'route', 'layers': '-1, 36'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '256',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '256',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'filters': '128',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'batch_normalize': '1',
#   'size': '3',
#   'stride': '1',
#   'pad': '1',
#   'filters': '256',
#   'activation': 'leaky'},
#  {'type': 'convolutional',
#   'size': '1',
#   'stride': '1',
#   'pad': '1',
#   'filters': '255',
#   'activation': 'linear'},
#  {'type': 'yolo',
#   'mask': '0,1,2',
#   'anchors': '10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326',
#   'classes': '80',
#   'num': '9',
#   'jitter': '.3',
#   'ignore_thresh': '.7',
#   'truth_thresh': '1',
#   'random': '1'}]

# %%
https://machinelearningspace.com/yolov3-tensorflow-2-part-2/
    
https://blog.paperspace.com/how-to-implement-a-yolo-v3-object-detector-from-scratch-in-pytorch-part-2/
